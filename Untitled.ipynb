# %%
import pandas as pd
from sqlalchemy import create_engine

# Load CSV
df = pd.read_csv("data/cleaned/fact_orders.csv")

# Connect to SQL
engine = create_engine("mysql+pymysql://root:Kitty%40123@localhost/sales_analytics")

# Insert into table
df.to_sql("fact_orders", con=engine, if_exists="replace", index=False)
# Out:
# 47145
